# %% [markdown]
# # <center> PROJECT - My First Assignment
# -------------

# %% [markdown]
# ## Introduction
# This notebook presents the development of a series of exercises aimed at completing my assignment of IBM Data Science Course. Each exercise is explained step by step, and in some cases, I provide different solutions to the same exercise. I hope you enjoy reading this notebook and, more importantly, learn something new.

# %% [markdown]
# ##### **Data Science Languages**
#
# -----
#
# In this chapter I present the most popular programming languages for use in Data Science:
#
# * <img src="https://cdn3.iconfinder.com/data/icons/logos-and-brands-adobe/512/267_Python-512.png" width="15" height="15"> Python : A high-level, general-purpose programming language. Ithas a large, standard library that provides tools
# suited to many different tasks, including Databases,
# Automation, Web scraping, Text processing, Image
# processing, Machine learning, and Data analytics.
#
# * <img src="https://cdn.icon-icons.com/icons2/2699/PNG/512/r_project_official_logo_icon_170811.png" width="15" height="15"> R : It's a statistical computing language.
#
# * <img src="https://static-00.iconduck.com/assets.00/sql-database-generic-icon-1521x2048-d0vdpxpg.png" width="15" height="15"> SQL: Structured Query Language that is non-procedural, usedfor querying and managing data.
#
# * <img src="https://cdn-icons-png.flaticon.com/512/6132/6132220.png" width="15" height="15"> Scala : It's a combination of scalable and language. A generalpurpose programming language that provides support forfunctional programming and is a strong static typesystem.
#
# * <img src="https://static-00.iconduck.com/assets.00/java-icon-1511x2048-6ikx8301.png" width="20" height="20"> Java : A general-purpose object-orinted programming language.
#
# * <img src="https://raw.githubusercontent.com/isocpp/logos/master/cpp_logo.png" width="15" height="15"> C++ : A general-purpose programming language. It is an
# extension of the C programming language or C
# with Classes.
#
# * <img src="https://static-00.iconduck.com/assets.00/julia-icon-512x331-jfujd98s.png" width="15" height="15"> Julia : A language for high-performance numerical analysis andcomputational science.
#
# * <img src="https://cdn-icons-png.flaticon.com/512/5968/5968292.png" width="15" height="15"> JavaScript : A general-purpose language that extended beyond the
# browser with the creation of Node.js and other serverside approaches.
#
# * <img src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSpEy7NDZaJgOuppMzPYrA32_z6IHI777Tn9g&s" width="20" height="20"> php : PHP (recursive acronym for PHP: Hypertext Preprocessor ) is a widely-used open source general-purpose scripting language that is especially suited for web development and can be embedded into HTML.
#
# * <img src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcThUnciBd-FsLrkbaaGgMVm2BFVVjSZONF3Tw&s" width="20" height="20"> Go: It's an open source programming language that makes it simple to build secure, scalable systems.
#
# * <img src="https://c0.klipartz.com/pngpicture/535/618/sticker-png-ruby-on-rails-computer-programming-programming-language-ruby-angle-rectangle-logo-computer-programming-ruby-thumbnail.png" width="15" height="15"> Ruby : It's an interpreted, high-level, general-purpose programming language

# %% [markdown]
# ##### **Data Science Libraries**
#
# -----
#
# Libraries are a collection opf functions and methods that allow you to perform many actions without writing the code. Following, I present the most popular libraries for some programming languages.
#
# ##### <img src="https://cdn3.iconfinder.com/data/icons/logos-and-brands-adobe/512/267_Python-512.png" width="15" height="15"> *Python Libraries*
#
# 1. Scientific Computing Libraries.
#
#     * Pandas (Data Structures & Tools).
#     * Numpy (Arrays & Matrices).
#
# 2. Visualization Libraries.
#
#     * Matplotlib (plots & graphs, most popular)
#     * Seaborn (plots: heatmaps, time series, histograms)
#
# 3. High-Level-Machine Learning and Deep Learning.
#
#     * Scikit-learn (Machine Learning: regression, classification, clustering)
#     * Keras (Deep Learning Neural Networks)
#     * TensorFlow (Deep Learning: Production and Deployment)
#     * PyTorch (Deep Learning: regression, classification)
#
#
# ##### <img src="https://cdn-icons-png.flaticon.com/512/6132/6132220.png" width="15" height="15"> *Scala Libraries*
#
# 1. Visualization Libraries.
#
#     * Vegas for statistical data visualizations
#
# 2. Deep Learning.
#
#     * Big DL for deep learning
#
#
# ##### <img src="https://cdn.icon-icons.com/icons2/2699/PNG/512/r_project_official_logo_icon_170811.png" width="15" height="15"> *R Libraries*
#
# 1. Visualization Libraries.
#
#     * ggplot2
#
# 2. Deep Learning.
#
#     * Keras and TensorFlow

# %% [markdown]
# ##### **Data Science Tools**
# ----
# Data science tools rely on four different categories:
# - Execution Environments.
# - Data Asset Management.
# - Code Asset Management.
# - Development Environments.
#
# -----
# **Execution Environments Tools**
# An execution environment has libraries for code compiling and system resources to execute and verify code.
#
# Some tools for execution environments are:
#
# - IBM Watson Studio
# - Jupyter
#
# -----
# **Data Management Tools**
#
# DAM is the organizing and managing of important data collected from different sources, it is performed on a DAM platform that allows versioning and collaboration.
#
#
# 1.  Data Management: It's the process of collecting, persisting and retrieving data securely, efficiently and cost-effectively.
#
#     Some open-source data management tools are relations databases like:
#
#     * Postgress
#     * Mongo
#     * MySQL
#     * Cassandra
#     * hadoop
#
# 2. Data Integration and Transformation: ETL, which stands for Extracting, Transforming, and Loading data, involves the process of transforming the values, structure, and format of the data.
#
#     Some data integration and transformation tools are:
#
#     * Apache Airflow
#     * Kubeflow
#     * Node Red
#     * Apache nifi
#     * Spark SQL
#
# 3. Data Visualization: Data visualization is the graphical representation of data and information. It effectively conveys data in a more understandable and impactful way.
#
#     Some data visualization tools are:
#
#     * PixieDust
#     * HUE
#     * Kibana
#     * Superset
#
# 4. Model Building: It's the step where you train the data and analyze patterns using suitable machine learning algorithms.
#
#     Some tools for model building are:
#
#     *  IBM Watson Studio
#
# 5. Model Deployment: Integrating a model into a production enviroment, it also uses APIs to enable data-based decisions.
#
#     Some tools for model deployment are:
#
#     * PredictionIO
#     * Seldon
#     * mleap
#     * kubernetes
#
# 6. Model Monitoring and Assessment: They run continuos quality checks to ensure a model's accuracy, fairness, and robustness.
#
#     * Model Monitoring: Tracks deployed models.
#     * Model Assessment: Checks for accuracy, fairness and robustness monitoring.
#
#     Some tools for model deployment are:
#
#     * Watson Studio IBM
#
# For Data Asset Management Tools are Apache Atlas, ODPi Egeria, and Kylo
#
# -------
# **Code Asset Management Tools**
#
# It is an unified view where you manage an inventory of assets and where developers use versioning to track and manage changes to a software project's code.
#
#
# Some tools for asset management are:
#
# - Git
# - GitLab
# - GitHub
#
# -------
# **Development Environments Tools**
#
# Integrated development environments provide a workspace and tools to develop, implement, execute, test, and deploy source code.
#
# Some tools for development environments are:
#
# - Watson Studio IBM
# - VSCode
# - Anaconda
# - PyCharm

# %% [markdown]
# | Category                 | Tools                                    |
# |--------------------------|------------------------------------------|
# | Execution Environments   | Jupyter Notebook,IBM Watson Studio   |
# | Data Asset Management    | Apache Atlas, ODPi Egeria, and Kylo   |
# | Code Asset Management    | GitHub, GitLab, Git               |
# | Development Environments | Anaconda, PyCharm, VSCode                |

# %% [markdown]
# ### Introduccion to arithmetic expressions
#
# Arithmetic expressions are fundamental in mathematics and programming. They involve basic operations such as addition, subtraction, multiplication, and division.
#
# Examples of arithmetic expressions include:
# - Addition: 5 + 3
# - Subtraction: 10 - 4
# - Multiplication: 6 * 7
# - Division: 15 / 3
#
# These expressions form the building blocks for more complex mathematical operations. In programming, they are used extensively for calculations and logic.

# %%
#This code allos you to make multiply and add numbers.

#Import Libraries
import math

operation = input("""
Welcome to Multiplication and Addition stage:

To select and operation type :
      1 - for Multiplication
      2 - for addition 
""")

if operation == '1':

    print('Type the multiplication you want to do - Example : 1*2*3*4')
    expression = input('')
    result = eval(expression)

elif operation == '2':

    print('Type the addition you want to do - Example : 1+2+3+4')
    expression = eval(input(''))
    result = eval(expression)

else :
    print('Try again')

print(f"The result is: {result}")
# Out:
# Type the multiplication you want to do - Example : 1*2*3*4
# The result is: 504

# %%
#This code allos you to make multiply and add numbers.

def convert_minutes_to_hours(minutes):
    hours = int(minutes)/ 60
    return hours

minutes = input('Enter the minutes: ')

print(f"The results is {convert_minutes_to_hours(minutes)} hours")
# Out:
# The results is 3.0 hours

# %% [markdown]
# ### Objectives:
#
# - Provide a step-by-step explanation of exercises to demonstrate proficiency in completing assignments for the IBM Data Science Course.
# - Present multiple solutions for some exercises to showcase versatility and understanding of different problem-solving approaches.
# - Offer an enjoyable reading experience for my peers while imparting new knowledge and insights related to data science concepts and techniques.
# - Encourage active learning and engagement by explaining each exercise in a clear and informative manner, fostering an environment for continuous learning and improvement.

# %% [markdown]
# **Author : Luis Carlos Rincón.**
